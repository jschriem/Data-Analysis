# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from math import log10
import numpy as np

labels=['Federer', 'Nadal', 'Djokovic', 'Murray', 'Wawrinka', 'Čilić', 'del Potro', 'Gaudio', 'Safin']
data = [19, 19, 16, 3, 3, 1,1,1,1]
#number of data points
n = len(data)
#find max value for full ring
k = 10 ** int(log10(max(data)))
m = k * (1 + max(data) // k)

# X-AXIS
x=[1, 3, 7, 11, 16, 19]

#radius of donut chart
r = 1.5
#calculate width of each ring
w = r / n 

#create colors along a chosen colormap
colors = [cm.plasma(i / n) for i in range(n)]

#create figure, axis
fig, ax = plt.subplots()
ax.axis("equal")

#create rings of donut chart
for i in range(n):
    #hide labels in segments with textprops: alpha = 0 - transparent, alpha = 1 - visible
    innerring, _ = ax.pie([m - data[i], data[i]], radius = r - i * w, startangle = 90, labels = ["", labels[i]], labeldistance = 1 - 1 / (1.5 * (n - i)), textprops = {"alpha": 0}, colors = ["white", colors[i]])
    plt.setp(innerring, width = w, edgecolor = "white")
    
ax.set_title('Grand Slam Wins in the Last 15 Years (2004 - 2019)', fontsize=20, )
ttl = ax.title
ttl.set_position([.54, 1.2])

xticks(np.arange(0, 1, step=0.2))

plt.legend(bbox_to_anchor=(0.9,0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-86ec6f54bae2> in <module>
#      37 ttl.set_position([.54, 1.2])
#      38
# ---> 39 xticks(np.arange(0, 1, step=0.2))
#      40
#      41 plt.legend(bbox_to_anchor=(0.9,0.5))
#
# NameError: name 'xticks' is not defined
